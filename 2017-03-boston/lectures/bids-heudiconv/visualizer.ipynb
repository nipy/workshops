# %%
import pandas as pd
import os

info = os.path.abspath('../../data/output/PHANTOM1_3/info/dicominfo.txt')
df = pd.read_csv(info, sep='\t')

# %%
from IPython.display import HTML

def hover(hover_color="#ffff99"):
    return dict(selector="tr:hover",
                props=[("background-color", "%s" % hover_color)])

styles = [
    hover(),
    dict(selector="th", props=[("font-size", "100%"),
                               ("text-align", "center")]),
    dict(selector="td", props=[("font-size", "80%")]),
    dict(selector="caption", props=[("caption-side", "bottom")])
]
html = (df.style.set_table_styles(styles)
          .set_caption("Hover to highlight."))
html
# Out:
#         <style  type="text/css" >
#
#             #T_636b8302_0f7c_11e7_8f5c_c82a1415174b tr:hover {
#
#                 background-color: #ffff99;
#
#             }
#
#             #T_636b8302_0f7c_11e7_8f5c_c82a1415174b th {
#
#                 font-size: 100%;
#
#                 text-align: center;
#
#             }
#
#             #T_636b8302_0f7c_11e7_8f5c_c82a1415174b td {
#
#                 font-size: 80%;
#
#             }
#
#             #T_636b8302_0f7c_11e7_8f5c_c82a1415174b caption {
#
#                 caption-side: bottom;
#
#             }
#
#
#         </style>
#
#         <table id="T_636b8302_0f7c_11e7_8f5c_c82a1415174b" None>
#
#             <caption>Hover to highlight.</caption>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   total_files_till_now
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   example_dcm_file
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   series_number
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   unspecified1
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   unspecified2
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   unspecified3
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   dim1
#
#
#
#                 <th class="col_heading level0 col7" colspan=1>
#                   dim2
#
#
#
#                 <th class="col_heading level0 col8" colspan=1>
#                   dim3
#
#
#
#                 <th class="col_heading level0 col9" colspan=1>
#                   dim4
#
#
#
#                 <th class="col_heading level0 col10" colspan=1>
#                   TR
#
#
#
#                 <th class="col_heading level0 col11" colspan=1>
#                   TE
#
#
#
#                 <th class="col_heading level0 col12" colspan=1>
#                   protocol_name
#
#
#
#                 <th class="col_heading level0 col13" colspan=1>
#                   is_motion_corrected
#
#
#
#                 <th class="col_heading level0 col14" colspan=1>
#                   is_derived
#
#
#
#                 <th class="col_heading level0 col15" colspan=1>
#                   patient_id
#
#
#
#                 <th class="col_heading level0 col16" colspan=1>
#                   study_description
#
#
#
#                 <th class="col_heading level0 col17" colspan=1>
#                   referring_physician_name
#
#
#
#                 <th class="col_heading level0 col18" colspan=1>
#                   series_description
#
#
#
#                 <th class="col_heading level0 col19" colspan=1>
#                   image_type
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_636b8302_0f7c_11e7_8f5c_c82a1415174b"
#                  class="row_heading level0 row0" rowspan=1>
#                     0
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col0"
#                  class="data row0 col0" >
#                     128
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col1"
#                  class="data row0 col1" >
#                     YAROSLAV.MR.HEAD_ADVANCED_APPLICATIONS_LIBRARIES.0001.0001.2016.08.24.11.53.51.544091.5157975.IMA
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col2"
#                  class="data row0 col2" >
#                     1-AAHead_Scout
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col3"
#                  class="data row0 col3" >
#                     -
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col4"
#                  class="data row0 col4" >
#                     -
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col5"
#                  class="data row0 col5" >
#                     -
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col6"
#                  class="data row0 col6" >
#                     160
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col7"
#                  class="data row0 col7" >
#                     160
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col8"
#                  class="data row0 col8" >
#                     128
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col9"
#                  class="data row0 col9" >
#                     1
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col10"
#                  class="data row0 col10" >
#                     0.00315
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col11"
#                  class="data row0 col11" >
#                     1.37
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col12"
#                  class="data row0 col12" >
#                     AAHead_Scout
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col13"
#                  class="data row0 col13" >
#                     False
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col14"
#                  class="data row0 col14" >
#                     False
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col15"
#                  class="data row0 col15" >
#                     dbic-test1
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col16"
#                  class="data row0 col16" >
#                     head^advanced applications libraries
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col17"
#                  class="data row0 col17" >
#                     nan
#
#
#
#                 <td id="T_636b8302_0f7c_11e7_8f5c_c82a1415174brow0_col18"
#                  class="data row0 col18" >
#                     AAHead_Scout

# %% [markdown]
# def magnify():
#     return [dict(selector="td",
#                  props=[("font-size", "2pt")]),
#             dict(selector="th",
#                  props=[("font-size", "10pt")]),
#             dict(selector="tr:hover",
#                  props=[('max-width', '50%'),
#                         ('font-size', '10pt')])
# ]
#
# zoom = (df.style.set_table_styles(magnify())
#           .set_caption("Hover to Magnify"))
# zoom
